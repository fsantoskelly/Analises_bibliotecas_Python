# %% [markdown]
# **Criando gráficos com a biblioteca MatplotLib**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix.csv')

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df.head()
# Out:
#                        Movie Title  Year  Score             Director  \
# 0                        His House  2020    100          Remi Weekes
# 1         How to Train Your Dragon  2010     99  Christopher Sanders
# 2       The Forty-Year-Old Version  2020     99          Radha Blank
# 3                 Under the Shadow  2016     99         Babak Anvari
# 4  Monty Python and the Holy Grail  1975     98        Terry Gilliam
#
#                                                 Cast  \
# 0  Wunmi Mosaku, Sope Dirisu, Matt Smith, Cornell...
# 1  Jay Baruchel, Gerard Butler, America Ferrera, ...
# 2  Welker White, Reed Birney, Radha Blank, Peter Kim
# 3  Narges Rashidi, Avin Manshadi, Bobby Naderi, R...
# 4  Graham Chapman, John Cleese, Terry Gilliam, Er...
#
#                                    Critics Consensus
# 0  Featuring genuine scares through every corrido...
# 1  Boasting dazzling animation, a script with sur...
# 2  The Forty-Year-Old Version opens a compelling ...
# ...

# %%
eixo_x = df['Score'].value_counts().keys()
eixo_y = df['Score'].value_counts().values

# %%
#Configurar gráfico de barras com eixos X e Y

plt.bar(eixo_x, eixo_y)

#Adicionar título do gráfico

plt.title('Ranking de Filmes')

#Adicionar rotação aos dados do eixo X do gráfico (neste caso em 45 graus)

plt.xticks(rotation=45)

#Adicionar títulos aos eixos X e Y

plt.xlabel('Nota do Ranking')
plt.ylabel('Numero de filmes')

#Mostrar gráfico
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Gráfico Ranking x Ano de Lançamento**

# %%
eixo_x = df['Year'].value_counts().sort_index().keys()
eixo_y = df['Year'].value_counts().sort_index().values

# %%
#Configurar gráfico de barras com eixos X e Y

plt.plot(eixo_x, eixo_y)

#Adicionar título do gráfico

plt.title('Filmes produzidos por ano')

#Adicionar rotação aos dados do eixo X do gráfico (neste caso em 45 graus)

plt.xticks(rotation=45)

#Adicionar títulos aos eixos X e Y

plt.xlabel('Ano do Filme')
plt.ylabel('Numero de filmes')

#Mostrar gráfico
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Configurar gráfico de barras com eixos X e Y

plt.scatter(eixo_x, eixo_y)

#Adicionar título do gráfico

plt.title('Filmes produzidos por ano')

#Adicionar rotação aos dados do eixo X do gráfico (neste caso em 45 graus)

plt.xticks(rotation=45)

#Adicionar títulos aos eixos X e Y

plt.xlabel('Ano do Filme')
plt.ylabel('Numero de filmes')

#Mostrar gráfico
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
